# %% [markdown]
# # 심층 신경망

# %% [markdown]
# ## 2개의 층

# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
from sklearn.model_selection import train_test_split

train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28*28)

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42)

# %%
dense1 = keras.layers.Dense(100, activation='sigmoid', input_shape = (784,))
dense2 = keras.layers.Dense(10, activation='softmax')

# dense1이 은닉층이고 100개의 뉴런을 가진 밀집층입니다. 활성화 함수를 시그모이드로 지정했습니다.
# dense2는 출력층입니다. 10개의 클래스를 분류하므로 10개의 뉴런을 두었고 소프트맥스 함수로 지정했습니다.

# %% [markdown]
# ## 심층 신경망 만들기

# %%
model = keras.Sequential([dense1, dense2])

# sequential클래스의 객체를 만들때 여러개의 층을 추가하려면 이와같이 dense1과 dense2를 리스트로 만들어 전달합니다.
# 주의할점은 출력층을 가장 마지막에 두어야합니다.

# %%
model.summary()

# 맨첫줄에 모델이름, 그다음 이 모델에 들어있는 층이 순서대로 나열된다. 이 순서는 맨 처음 추가한 은닉층에서 출력층의 순서대로 나열된다.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 층을 추가하는 다른 방법

# %%
model = keras.Sequential([
                          keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name = 'hidden'),
                          keras.layers.Dense(10, activation='softmax', name = 'output')], name = '패션 MNIST 모델'
)

# %%
model.summary()
# Out:
# Model: "패션 MNIST 모델"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape = (784,)))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 100)               78500
#
#  dense_3 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')

model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5672 - accuracy: 0.8081
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4073 - accuracy: 0.8551
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3724 - accuracy: 0.8656
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3507 - accuracy: 0.8734
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3349 - accuracy: 0.8787
